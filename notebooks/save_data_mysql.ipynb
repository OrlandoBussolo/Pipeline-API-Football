# %% [markdown]
# ## Configurando o MySQL com Python

# %% [markdown]
# Neste momento, vamos configurar a integração entre o MySQL e Python. Isso nos permitirá executar consultas, inserções e outras operações no banco de dados MySQL usando o Python como nossa linguagem de programação principal.

# %%
def connect_mysql(host_name, user_name, pw):
    cnx = mysql.connector.connect(
        host = host_name,
        user = user_name,
        password = pw
    )
    
    return cnx

# %%
a = connect_mysql('localhost','orlando_bussolo', 'asdfg...')
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x7f2b7da7ca60>

# %% [markdown]
# Criaremos um cursor, que é um objeto utilizado para executar instruções SQL no contexto do Python. Essse cursor nos permitirá enviar consultas e comandos SQL para o banco de dados MySQL por meio da conexão estabelecida e obter os resultados de volta para serem processados em nosso código Python

# %%
def create_cursor(cnx):
    cursor = cnx.cursor()
    return cursor
    print(cursor)

# %%
b = create_cursor(a)

# %% [markdown]
# ## Criando uma base de dados

# %% [markdown]
# O método `execute()` é usado para compilar uma instrução SQL

# %%
# Out:
# ('db_games',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
cursor.execute("USE db_games")
cursor.execute("SHOW TABLES")
for a in cursor:
    print(a)
# Out:
# ('premiere_league',)

# %%
def create_database(cursor, db_name):
    cursor.execute(f"CREATE DATABASE IF NOT EXISTS,{db_name}")
    print(f"\nBase de dados {db_name} criada")

# %% [markdown]
# ## Criando uma tabela

# %% [markdown]
# Antes de criar nossa tabela, vamos revisar as colunas necessárias que precisaremos incluir nela. Essa etapa é importante para garantir que nossa tabela seja projetada corretamente, atendendo aos requisitos de armazenamento e organização dos dados.

# %%
 df = pd.read_csv("/home/orlando_linux/pipeline-python-mongo-mysql/data_teste/tabela.csv")

# %% [markdown]
# **Selecionando a base de dados para verificar a tabela criada**

# %% [markdown]
# ## Inserindo os dados do csv na tabela

# %% [markdown]
# Para inserir os dados na tabela do MySQL, é necessário percorrer cada linha do DataFrame e transformá-las em tuplas. Essa abordagem permite que mapeemos os dados do DataFrame para as colunas correspondentes da tabela do MySQL de forma eficiente e precisa.

# %%
import mysql.connector
import pandas as pd

cnx = mysql.connector.connect(
        host = 'localhost',
        user = 'orlando_bussolo',
        password = 'asdfg...'
    )

cursor = cnx.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS db_games")

cursor.execute("SHOW DATABASES")
for x in cursor:
    print(x)
# Out:
# ('db_games',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
cursor.execute("""
        CREATE TABLE IF NOT EXISTS db_games.premiere_league(
        
        match_id INT,
        league_id INT,
        match_date DATE,
        match_time TIME,
        match_hometeam_id INT,
        match_hometeam_name VARCHAR(255),
        match_hometeam_score INT,
        match_awayteam_name VARCHAR(255),
        match_awayteam_id INT,
        match_awayteam_score INT,
        match_round INT,
        match_stadium VARCHAR(255),
        match_referee VARCHAR(255),
        league_year VARCHAR(50),
                
        PRIMARY KEY (match_id)
    )""")

# %%
cursor.execute("USE db_games")
cursor.execute("SHOW TABLES")
for x in cursor:
    print(x)
# Out:
# ('premiere_league',)

# %%
 df = pd.read_csv("/home/orlando_linux/pipeline-python-mongo-mysql/data_teste/tabela.csv")
df.head(1)
# Out:
#    match_id  league_id  match_date match_time  match_hometeam_id  \
# 0    206506        152  2024-01-30      21:15               3088
#
#   match_hometeam_name  match_hometeam_score match_awayteam_name  \
# 0         Aston Villa                   1.0    Newcastle United
#
#    match_awayteam_id  match_awayteam_score  match_round  \
# 0               3100                   3.0           22
#
#              match_stadium match_referee league_year
# 0  Villa Park (Birmingham)     J. Brooks   2023/2024

# %%
for i, row in df.iterrows():
    tuple(row)

# %%
import numpy as np
lista = [tuple(row) for i, row in df.iterrows() ]
lista = [tuple(None if pd.isna(item) else item for item in tupla) for tupla in lista]


print(lista)
# Out:
# [(206506, 152, '2024-01-30', '21:15', 3088, 'Aston Villa', 1.0, 'Newcastle United', 3100, 3.0, 22, 'Villa Park (Birmingham)', 'J. Brooks', '2023/2024'), (206507, 152, '2024-01-30', '20:45', 3085, 'Fulham', 0.0, 'Everton', 3073, 0.0, 22, 'Craven Cottage (London)', 'T. Bramall', '2023/2024'), (206508, 152, '2024-01-30', '20:45', 3091, 'Luton Town', 4.0, 'Brighton & Hove Albion', 3079, 0.0, 22, 'Kenilworth Road (Luton, Bedfordshire)', 'R. Jones', '2023/2024'), (206509, 152, '2024-01-30', '20:30', 3089, 'Nottingham Forest', 1.0, 'Arsenal', 141, 2.0, 22, 'The City Ground (Nottingham, Nottinghamshire)', 'S. Hooper', '2023/2024'), (206513, 152, '2024-01-30', '21:00', 3429, 'Crystal Palace', 3.0, 'Sheffield United', 3074, 2.0, 22, 'Selhurst Park (London)', 'T. Harrington', '2023/2024'), (206510, 152, '2024-01-31', '20:30', 164, 'Tottenham Hotspur', 3.0, 'Brentford', 3086, 2.0, 22, 'Tottenham Hotspur Stadium (London)', 'D. Coote', '2023/2024'), (206514, 152, '2024-01-31', '21:15', 84, 'Liverpool', 4.0, 'Chelsea', 88, 1.0, 22, 'Anfield (Liverpool)', 'P. Tierney', '2023/2024'), (206515, 152, '2024-01-31', '20:30', 80, 'Manchester City', 3.0, 'Burnley', 3075, 1.0, 22, 'Etihad Stadium (Manchester)', 'S. Barrott', '2023/2024'), (206511, 152, '2024-02-01', '20:30', 3081, 'West Ham United', 1.0, 'AFC Bournemouth', 3071, 1.0, 22, 'London Stadium (London)', 'T. Robinson', '2023/2024'), (206512, 152, '2024-02-01', '21:15', 3077, 'Wolverhampton Wanderers', 3.0, 'Manchester United', 102, 4.0, 22, 'Molineux Stadium (Wolverhampton, West Midlands)', 'J. Gillett', '2023/2024'), (206525, 152, '2024-02-03', '18:30', 3074, 'Sheffield United', 0.0, 'Aston Villa', 3088, 5.0, 23, 'Bramall Lane (Sheffield)', 'P. Tierney', '2023/2024'), (206524, 152, '2024-02-03', '16:00', 3100, 'Newcastle United', 4.0, 'Luton Town', 3091, 4.0, 23, "St. James' Park (Newcastle upon Tyne)", 'T. Bramall', '2023/2024'), (206522, 152, '2024-02-03', '13:30', 3073, 'Everton', 2.0, 'Tottenham Hotspur', 164, 2.0, 23, 'Goodison Park (Liverpool)', 'M. Oliver', '2023/2024'), (206520, 152, '2024-02-03', '16:00', 3075, 'Burnley', 2.0, 'Fulham', 3085, 2.0, 23, 'Turf Moor (Burnley)', 'D. Bond', '2023/2024'), (206519, 152, '2024-02-03', '16:00', 3079, 'Brighton & Hove Albion', 4.0, 'Crystal Palace', 3429, 1.0, 23, 'American Express Stadium (Falmer, East Sussex)', 'S. Hooper', '2023/2024'), (206517, 152, '2024-02-04', '17:30', 141, 'Arsenal', 3.0, 'Liverpool', 84, 1.0, 23, 'Emirates Stadium (London)', 'A. Taylor', '2023/2024'), (206521, 152, '2024-02-04', '15:00', 88, 'Chelsea', 2.0, 'Wolverhampton Wanderers', 3077, 4.0, 23, 'Stamford Bridge (London)', 'T. Robinson', '2023/2024'), (206516, 152, '2024-02-04', '15:00', 3071, 'AFC Bournemouth', 1.0, 'Nottingham Forest', 3089, 1.0, 23, 'Vitality Stadium (Bournemouth, Dorset)', 'R. Welch', '2023/2024'), (206523, 152, '2024-02-04', '15:00', 102, 'Manchester United', 3.0, 'West Ham United', 3081, 0.0, 23, 'Old Trafford (Manchester)', 'A. Madley', '2023/2024'), (206518, 152, '2024-02-05', '21:00', 3086, 'Brentford', 1.0, 'Manchester City', 80, 3.0, 23, 'Gtech Community Stadium (Brentford, Middlesex)', 'J. Gillett', '2023/2024'), (206530, 152, '2024-02-10', '16:00', 3091, 'Luton Town', 1.0, 'Sheffield United', 3074, 3.0, 24, 'Kenilworth Road (Luton, Bedfordshire)', 'C. Kavanagh', '2023/2024'), (206531, 152, '2024-02-10', '13:30', 80, 'Manchester City', 2.0, 'Everton', 3073, 0.0, 24, 'Etihad Stadium (Manchester)', 'J. Brooks', '2023/2024'), (206535, 152, '2024-02-10', '16:00', 3077, 'Wolverhampton Wanderers', 0.0, 'Brentford', 3086, 2.0, 24, 'Molineux Stadium (Wolverhampton, West Midlands)', 'S. Hooper', '2023/2024'), (206532, 152, '2024-02-10', '18:30', 3089, 'Nottingham Forest', 2.0, 'Newcastle United', 3100, 3.0, 24, 'The City Ground (Nottingham, Nottinghamshire)', 'A. Taylor', '2023/2024'), (206533, 152, '2024-02-10', '16:00', 164, 'Tottenham Hotspur', 2.0, 'Brighton & Hove Albion', 3079, 1.0, 24, 'Tottenham Hotspur Stadium (London)', 'S. Barrott',  ...

# %%
sql = "INSERT INTO db_games.premiere_league VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"

cursor.executemany(sql, lista)
#print(f"\n {cursor.rowcount} dados foram inseridos na tabela premiere_league.")
cnx.commit()

# %% [markdown]
# ## Visualizando os dados inseridos
